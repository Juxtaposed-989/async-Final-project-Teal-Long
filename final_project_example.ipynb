# %%
# !pip install matplotlib.pyplot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Users\longs\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for matplotlib.pyplot

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset. Replace 'titanic.csv' with your own dataset file for your project.
# Ensure the dataset file exists and is in the same directory as this jupyter notebook.
Covid_df = pd.read_csv('Covid CSV.csv')
Air_df = pd.read_csv('Air Quality(Back Up).csv')

# Display the first few rows of the dataframe to ensure it is loaded correctly
display(Covid_df['COVID_deaths'].notnull().sum())
display(Covid_df.tail(10))

display(Covid_df.columns)
display()
Covid_df['data_period_start']
# Out:
# np.int64(33540)
#        data_as_of Jurisdiction_Residence           Group data_period_start  \
# 38015  08/07/2025              Tennessee  3 month period        05/11/2025
# 38016  08/07/2025                  Texas  3 month period        05/11/2025
# 38017  08/07/2025          United States  3 month period        05/11/2025
# 38018  08/07/2025                   Utah  3 month period        05/11/2025
# 38019  08/07/2025                Vermont  3 month period        05/11/2025
# 38020  08/07/2025               Virginia  3 month period        05/11/2025
# 38021  08/07/2025             Washington  3 month period        05/11/2025
# 38022  08/07/2025          West Virginia  3 month period        05/11/2025
# 38023  08/07/2025              Wisconsin  3 month period        05/11/2025
# 38024  08/07/2025                Wyoming  3 month period        05/11/2025
#
#       data_period_end  COVID_deaths  COVID_pct_of_total  pct_change_wk  \
# 38015      08/02/2025          42.0                 0.3            NaN
# 38016      08/02/2025         119.0                 0.3            NaN
# 38017      08/02/2025        1996.0                 0.3            NaN
# 38018      08/02/2025           NaN                 NaN            NaN
# 38019      08/02/2025           NaN                 NaN            NaN
# 38020      08/02/2025          46.0                 0.3            NaN
# 38021      08/02/2025          56.0                 0.4            NaN
# 38022      08/02/2025           NaN                 NaN            NaN
# 38023      08/02/2025          18.0                 0.2            NaN
# 38024      08/02/2025           NaN                 NaN            NaN
#
#        pct_diff_wk  crude_COVID_rate  aa_COVID_rate  crude_COVID_rate_ann  \
# 38015          NaN               0.6            0.5                   2.6
# 38016          NaN               0.4            0.4                   1.8
# 38017          NaN               0.6            0.5                   2.6
# 38018          NaN               NaN            NaN                   NaN
# 38019          NaN               NaN            NaN                   NaN
# 38020          NaN               0.5            0.4                   2.3
# 38021          NaN               0.7            0.7                   3.1
# 38022          NaN               NaN            NaN                   NaN
# 38023          NaN               NaN            NaN                   NaN
# 38024          NaN               NaN            NaN                   NaN
#
#        aa_COVID_rate_ann                                           footnote
# 38015                2.3                                                NaN
# 38016                1.9                                                NaN
# 38017                2.2                                                NaN
# 38018                NaN  Death counts between 1-9 are suppressed. Rates...
# 38019                NaN  Death counts between 1-9 are suppressed. Rates...
# 38020                1.9                                                NaN
# 38021                3.0                                                NaN
# 38022                NaN  Death counts between 1-9 are suppressed. Rates...
# 38023                NaN         Rates for death counts <20 are unreliable.
# 38024                NaN  Death counts between 1-9 are suppressed. Rates...
# Index(['data_as_of', 'Jurisdiction_Residence', 'Group', 'data_period_start',
#        'data_period_end', 'COVID_deaths', 'COVID_pct_of_total',
#        'pct_change_wk', 'pct_diff_wk', 'crude_COVID_rate', 'aa_COVID_rate',
#        'crude_COVID_rate_ann', 'aa_COVID_rate_ann', 'footnote'],
#       dtype='object')
# 0        01/01/2020
# 1        01/01/2020
# 2        01/01/2020
# 3        01/01/2020
# 4        01/01/2020
#             ...
# 38020    05/11/2025
# 38021    05/11/2025
# 38022    05/11/2025
# 38023    05/11/2025
# 38024    05/11/2025
# Name: data_period_start, Length: 38025, dtype: object
